# %%
matrix = []

print("Enter 9 elements:")

# Input matrix
for i in range(3):
    row = []
    for j in range(3):
        num = int(input())
        row.append(num)
    matrix.append(row)

# Print secondary diagonal elements
print("Secondary Diagonal Elements:")

for i in range(3):
    print(matrix[i][2 - i], end=" ")
