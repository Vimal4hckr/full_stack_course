# %%
matrix = []

print("Enter 9 elements:")

# Input matrix
for i in range(3):
    row = []
    for j in range(3):
        num = int(input())
        row.append(num)
    matrix.append(row)

# Sum of each row
for i in range(3):
    total = 0
    for j in range(3):
        total += matrix[i][j]
    print("Sum of Row", i + 1, "=", total)
# Out:
# Enter 9 elements:
# Sum of Row 1 = 3
# Sum of Row 2 = 3
# Sum of Row 3 = 3
